# %%
import pandas as pd

# %matplotlib inline

pd.__version__
# Out:
# '0.24.2'

# %%
df = pd.read_csv('./data/2017.csv')

# %%
df.shape
# Out:
# (155, 12)

# %%
df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %% [markdown]
# 顯示所有的 columns

# %%
df.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df.Freedom.describe()
# Out:
# count    155.000000
# mean       0.408786
# std        0.149997
# min        0.000000
# 25%        0.303677
# 50%        0.437454
# 75%        0.516561
# max        0.658249
# Name: Freedom, dtype: float64

# %% [markdown]
# 選擇 Freedom > 0.5 的 dataframe

# %%
df.query('Freedom > 0.5')
# Out:
#                   Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                  Norway               1            7.537      7.594445
# 1                 Denmark               2            7.522      7.581728
# 2                 Iceland               3            7.504      7.622030
# 3             Switzerland               4            7.494      7.561772
# 4                 Finland               5            7.469      7.527542
# 5             Netherlands               6            7.377      7.427426
# 6                  Canada               7            7.316      7.384403
# 7             New Zealand               8            7.314      7.379510
# 8                  Sweden               9            7.284      7.344095
# 9               Australia              10            7.284      7.356651
# 11             Costa Rica              12            7.079      7.168112
# 12                Austria              13            7.006      7.070670
# ...

# %% [markdown]
# 轉置（transpose）dataframe

# %%
df.T
# Out:
#                                     0         1         2            3    \
# Country                          Norway   Denmark   Iceland  Switzerland
# Happiness.Rank                        1         2         3            4
# Happiness.Score                   7.537     7.522     7.504        7.494
# Whisker.high                    7.59444   7.58173   7.62203      7.56177
# Whisker.low                     7.47956   7.46227   7.38597      7.42623
# Economy..GDP.per.Capita.        1.61646   1.48238   1.48063      1.56498
# Family                          1.53352   1.55112   1.61057      1.51691
# Health..Life.Expectancy.       0.796667  0.792566  0.833552     0.858131
# Freedom                        0.635423  0.626007  0.627163     0.620071
# Generosity                     0.362012   0.35528   0.47554     0.290549
# Trust..Government.Corruption.  0.315964   0.40077  0.153527     0.367007
# Dystopia.Residual               2.27703   2.31371   2.32272      2.27672
#
# ...

# %% [markdown]
# 捨棄不需要的欄位 (columns)

# %%
df.drop('Family', axis=1)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# 5                 Netherlands               6            7.377      7.427426
# 6                      Canada               7            7.316      7.384403
# 7                 New Zealand               8            7.314      7.379510
# 8                      Sweden               9            7.284      7.344095
# 9                   Australia              10            7.284      7.356651
# 10                     Israel              11            7.213      7.279853
# ...

# %% [markdown]
# 捨棄某欄位 (row)，這裡的 axis=0

# %%
df.drop(0)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# 5                 Netherlands               6            7.377      7.427426
# 6                      Canada               7            7.316      7.384403
# 7                 New Zealand               8            7.314      7.379510
# 8                      Sweden               9            7.284      7.344095
# 9                   Australia              10            7.284      7.356651
# 10                     Israel              11            7.213      7.279853
# 11                 Costa Rica              12            7.079      7.168112
# ...
